# %%
   

def salarytohourly():
    salary = int(input("Enter salary in plain text:"))
    salaryt = str(salary)
    hourly = int(salary/52/40)
    overtime = str(int(int(hourly)*1.5))
    return(f"With a salary of {salaryt}, hourly pay is {hourly}, overtime pay is {overtime}.")
salarytohourly()

# %%
def VOID_hourlytosalary_VOID(hourly):
    weekly = hourly*40
    overtime_probe = input("Is there over time paid on this salary? Y or N.")
    if overtime_probe.upper() == "Y":  ###broken. wont trigger correctly. a simple thing too. just cant figure it out though.
        overtime_rate = int(input("What rate is over time? Ex: '1.5' is time and a half"))
        overtime_expected_amount = int(input(
            "How many overtime hours are you expected to recieve pay for on average per week?: \nAssumes 40 hour standard workweek. \nPlease use whole numbers:"
            ))
        overtime = str(int(hourly*overtime_rate)(overtime_expected_amount))
        salary = (overtime + weekly)*52
        return(f"Including the expected overtime the salary is {salary}.")
    elif overtime_probe:
        salary = weekly*52
        return(f"The salary for this hourly rate is {salary}.")
    else:
        return(f"Something went wrong please restart.")
VOID_hourlytosalary_VOID(19)

# %%
def hourlytosalary():
    hourly = int(input("What is the hourly pay?"))
    weekly = hourly*40
    overtime_probe = input("Is there over time paid on this salary? Y or N: ")
    if overtime_probe.lower() == "y":  ###broken. wont trigger correctly. a simple thing too. just cant figure it out though.
        overtime_rate = float(input("What rate is over time? Ex: '1.5' is time and a half: "))
        overtime_expected_amount = int(input(
            "How many overtime hours are you expected to recieve pay for on average per week?\nAssumes 40 hour standard workweek.\nPlease use whole numbers: "
            ))
        print(overtime_expected_amount)
        overtime = hourly*overtime_rate*overtime_expected_amount
        salary = (overtime + weekly)*52
        result = (f"Including the expected overtime the salary is {salary}.")
        return(result)
    elif overtime_probe.lower() == "n":
        salary = weekly*52
        result = (f"The salary for this hourly rate is {salary}.")
        return(result)
    else:
        result = (f"Something went wrong please restart.")
        return(result)
hourlytosalary()

# %% [markdown]
# Ok so now i have the two function working which will make the next code look a lot cleaner for one. and I guess how I decided to come about making this particular document at this time. ok now lets add these together.

# %%
def paycalculator():
    decision = input("Enter H for Hourly or enter S for Salary.")
    if decision.lower() == "h":
        result = hourlytosalary()
        print(result)
    elif decision.lower() == "s":
        result = salarytohourly()
        print(result)
paycalculator()
